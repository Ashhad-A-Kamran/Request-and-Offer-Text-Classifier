# %% [markdown]
# # Creating Dataset Using Faker

# %%
import random
import pandas as pd
from faker import Faker
from datetime import datetime, timedelta

# Initialize Faker
fake = Faker()

# Define possible transport types and cities
transport_types = ["Offer", "Request", "Unknown"]
cities = [fake.city() for _ in range(10)]
price_range = [round(random.uniform(50, 500), 2) for _ in range(20)]
contact_numbers = [fake.phone_number() for _ in range(30)]

# Function to generate random transport messages
def generate_random_message():
    transport_type = random.choice(transport_types)
    departure_location = random.choice(cities) if transport_type != "Unknown" else None
    arrival_location = random.choice(cities) if transport_type != "Unknown" else None
    departure_date = (datetime.now() - timedelta(days=random.randint(1, 365))).strftime('%d/%m/%Y')
    departure_time = fake.time()
    price = random.choice(price_range) if transport_type == "Offer" else None
    contact_number = random.choice(contact_numbers) if transport_type != "Unknown" else None
    user_name = fake.name()
    user_id = fake.uuid4()

    # Generate message text
    if transport_type == "Offer":
        message = f"Lift offered from {departure_location} to {arrival_location} on {departure_date} at {departure_time}. Contact {contact_number}."
    elif transport_type == "Request":
        message = f"Lift requested from {departure_location} to {arrival_location} on {departure_date}. Please call {contact_number}."
    else:
        message = f"Doing trips between {departure_location} and {arrival_location}. Join our WhatsApp group for more details."
    
    return {
        "text": message,
        "time": datetime.now().strftime('%Y-%m-%dT%H:%M:%S.000Z'),
        "user_id": user_id,
        "user_name": user_name,
        "departure_location": departure_location,
        "departure_date": departure_date,
        "departure_time": departure_time,
        "arrival_location": arrival_location,
        "price": price,
        "contact_number": contact_number,
        "transport_type": transport_type
    }

# Generate 500 random messages
generated_messages = [generate_random_message() for _ in range(500)]

# Convert the data to a pandas DataFrame
df = pd.DataFrame(generated_messages)

# Save the DataFrame to an Excel file
output_file = "generated_transport_data.xlsx"
df.to_excel(output_file, index=False)

print(f"Data exported to {output_file}")
# Out:
# Data exported to generated_transport_data.xlsx

# %% [markdown]
# # Import necessary Libraries

# %%
import pandas as pd
import re
import os
from dotenv import load_dotenv
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, CategoriesOptions
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
load_dotenv()

# %% [markdown]
# # Initialize IBM Watson NLU Service

# %%
def initialize_ibm_watson_nlu(api_key, service_url):
    authenticator = IAMAuthenticator(api_key)
    nlu = NaturalLanguageUnderstandingV1(
        version='2023-09-26',
        authenticator=authenticator
    )
    nlu.set_service_url(service_url)
    return nlu

# %% [markdown]
# # Clean text messages (remove emojis, special characters, etc.)

# %%
def clean_message(message):
    # Remove emojis and other non-standard characters
    message = re.sub(r'[^\x00-\x7F]+', '', message)
    # Remove special characters except abbreviations like FL, GEN (all caps)
    message = re.sub(r'[^a-zA-Z0-9\s]', '', message)
    return message

# %% [markdown]
# # Send message to IBM NLU for information extraction

# %%
def analyze_message(nlu, message):
    try:
        response = nlu.analyze(
            text=message,
            features=Features(
                entities=EntitiesOptions(emotion=False, sentiment=False, limit=10),
                categories=CategoriesOptions(limit=1)
            )
        ).get_result()
        return response
    except Exception as e:
        print(f"Error processing message: {message}, Error: {str(e)}")
        return None

# %% [markdown]
# # Extract phone number, date, time from the message

# %%
def extract_information(nlu_response):
    phone_number, date, time = None, None, None  # Initialize variables
    entities = nlu_response.get('entities', [])
    for entity in entities:
        if entity['type'] == 'PhoneNumber':
            phone_number = entity['text']
        elif entity['type'] == 'Date':
            date = entity['text']
        elif entity['type'] == 'Time':
            time = entity['text']
    return phone_number, date, time

# %% [markdown]
# # Categorize message as 'request' or 'offer'

# %%
def categorize_message(message):
    message = message.lower()
    if 'request' in message or 'need a ride' in message:
        return 'request'
    elif 'offer' in message or 'giving a ride' in message:
        return 'offer'
    else:
        return 'unknown'

# %% [markdown]
# # Match similar requests and offers (simple matching based on location)

# %%
def match_requests_and_offers(df):
    matched_rides = []
    requests = df[df['Category'] == 'request']
    offers = df[df['Category'] == 'offer']

    for _, req in requests.iterrows():
        for _, offer in offers.iterrows():
            if req['Departure Location'] == offer['Departure Location'] and req['Arrival Location'] == offer['Arrival Location']:
                matched_rides.append({
                    'Request': req['Message'],
                    'Offer': offer['Message'],
                    'Request Phone': req['Phone Number'],
                    'Offer Phone': offer['Phone Number'],
                    'Departure': req['Departure Location'],
                    'Arrival': req['Arrival Location']
                })
    return matched_rides

# %% [markdown]
# # Main function to process messages

# %%
def process_carpool_messages(file_path, api_key, service_url):
    # Initialize NLU
    nlu = initialize_ibm_watson_nlu(api_key, service_url)

    # Load messages from Excel
    df = pd.read_excel(file_path)

    # Clean messages and extract information
    results = []
    for i, row in df.iterrows():
        message = clean_message(row['text'])
        nlu_response = analyze_message(nlu, message)

        # Skip if NLU response is None
        if nlu_response is None:
            continue

        phone_number, date, time = extract_information(nlu_response)
        category = categorize_message(message)
        
        # For simplicity, extracting location based on assumption
        departure_location = re.search(r'(from\s+[A-Z]+)', message)
        arrival_location = re.search(r'(to\s+[A-Z]+)', message)

        results.append({
            'Message': message,
            'Phone Number': phone_number,
            'Date': date,
            'Time': time,
            'Category': category,
            'Departure Location': departure_location.group(1) if departure_location else None,
            'Arrival Location': arrival_location.group(1) if arrival_location else None
        })

    # Convert results into DataFrame
    result_df = pd.DataFrame(results)

    # Match requests and offers
    matched_rides = match_requests_and_offers(result_df)

    return result_df, matched_rides

# %% [markdown]
# # Running the code

# %%
if __name__ == '__main__':
    API_KEY = os.getenv("IBM_API_KEY")
    SERVICE_URL = 'https://api.eu-de.natural-language-understanding.watson.cloud.ibm.com/instances/a23cfb67-2e4e-40d4-87ac-9a74b7e94f96'
    FILE_PATH = 'Tests Extract data 250924.xlsx'  # Path to your Excel file containing messages

    processed_data, matched_rides = process_carpool_messages(FILE_PATH, API_KEY, SERVICE_URL)
    
    # Print matched rides
    if matched_rides:
        for ride in matched_rides:
            print(f"Request: {ride['Request']}, Offer: {ride['Offer']}, Departure: {ride['Departure']}, Arrival: {ride['Arrival']}")
    else:
        print("No matched rides found.")
# Out:
# Error processing message: MOLWENi MANDIQALE NGE FOWNI KWEZELA NINGALAHLEKE CALLWTSPP 0665757443 IGAMA LAM NDINGU AYANDA MASILE NDIHLALA DUBARN EKHAYA KUSE EASTERN CAPE EMTHATHA TRANSKEI NDIFUNA KUNIXELELA NINA NONKE KUBA NDIHLUPHEKE IXESHA ELIDE  NGIKHANGELA U NCEDO LWEMALI KODWA BENDILAHLE NJE IMALI ZAMI EMVA KOKUBONA IPOST YOMNYE USISI NDILEKA APA KU FACEBOOK UMNCOMA UBABA UKHUMALO NAM NDATI MANDIMZAME  NDATHETHA NAYE UBABA UKHUMALO NYAN UBABA UKhUMALO WACELA ACCOUNT YAM NDAMNIKA NYAN UTHI NDILINDE 32 MINUTES NDABONA MESSAGE INGENA KWI ACCOUNT YAM KWANGENA R 38 MILLION YHO KHUBULELWA KWAM NDAMBHATALA 600 THAWUSANDE SO XA NIFUNA NANILUNCEDO PLZ  UBABA Khumalo CALL WHTSPP 0665757443  KWABANYE FOWNELA UBABA   KhumAL0 CALL OR WHATSAPP 0665757443 Makhosi, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: b776f6ab-ff88-452b-a799-793ca0092d92
# Error processing message: 0826275920Molweni igama lam ndingu Foad King
#  ndise Kapa kodwa ekhaya kuse Mthatha  ndifuna ukunixelela nonke nina uba ndihlupheke ixesha elide  Ndazobona post yomnye usis onguNwabisa apha kufacebook encoma uBaba KAWOMBE ngoba wamnceda ngemali esheshayo ndathi mandizame nam hleze ndngancedakala  nyan ndambhalela wathi mandithumele iAccount yam ndamnika after i1hour yangena imali kwi Account yam R6 million  awubhatali ubhatala after ingenile imali   Ndithi nani ningancami kuqale kubemnyama before kukhanye ungamfounela apha okanye whatsapp  0826275920, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: 38058862-7456-4b94-a292-6931c1e9dc38
# Error processing message: Nikombela vanhu va 3 midzuku na pundzu from Mindrandtembisa na pta   to GiyaniMalamulele, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: f302fda4-7c7f-471f-8fd5-454799d89b1a
# Error processing message: Laa yaku kaya 2moro ka Wayeniani byili pls, Error: Error: unsupported text language: sw, Status code: 400 , X-global-transaction-id: a6788820-d9a9-4a0a-89aa-5f87aca2fd8e
# Error processing message: Seme Phoho , Error: Error: not enough text for language id, Status code: 422 , X-global-transaction-id: 1266bdf3-42a1-4ef7-bf75-75435e5cf781
# Error processing message: Akekho oyosukumela isimo sempilo
# Yakho ngaphandle kwakho
# Ukuze uphile impilo engconothatha isinqumo esoshintsha impilo Yakho nesizukulwane sakho esizayoubuhlwempu singabuqeda masibambisana sibungaze amandla amathonga
#
# Whatsapp and call 078 629 6302 Udinga malini imali ozokwazi ukujabula impilo yakho yonke  ngisho imali esheshayo ngisiza umuntu kuqala nge 32 years kuyaphezulu  umuntu ngifuna umuntu Abecrc ongithintayo kube umuntu o serious hayi umuntu onesikhathi sokudlalaImali esheshayo namuhla engena endlin R64million noma kwi account yakho iyangena noma ukude Capitec Bank  R10 million FNB Bank  R9 million ABSA Bank  R82million Nedbank R8 million Standard Bank R79million Tyme Bank R7million African Bank R6million Bidvest Bank R58million Bhala ibhange lakho bese ulinda 45 minutes ngoba umsebenzi walapha ekhaya awunabungozi ungasabe akekho umunthu azoshonayo lapho  whatsapp and call 078 629 6302, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 2eadb98e-d011-4e2d-ac6b-9716558becc6
# Error processing message: Mikombela lift minduku nampundu kumbe namadyambu nisuka tembisa niya vuwani
#
# 0722698071, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: 4cb92df9-b274-430f-b973-61eead25155e
# Error processing message: Ndicela ilift from Mthatha to BishoKWT namhlanje ekuseni 0732354787, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: 2decd2be-d172-4ae1-a7fa-5f05ffec1dfc
# Error processing message: Ngiphinde ngibongele Iaba eseba phumelele
#
# Nawe ungasali ngaphandle kuyikhathi zakadecember ngiwhatsapp manje usizakale 0717953310
#
# Ngo R450 wenkanyiso ngikwezela u R1 million xhumana nami kule number 0717953310 ngyatholakala kuwhatsapp, Error: Error: unsupported text language: ndebele, Status code: 400 , X-global-transaction-id: 80ab7d5e-b21b-405e-a1b9-be85987c2ac8
# Error processing message: Cela ilift for umntu usuka emount frere uza ekapa for Friday, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: eb0c1caa-f8cf-4fa5-8125-64208e6a19e2
# Error processing message: Baba bongani CALL OR WATSSAP 0683103614
#
# ngisiza abantu izinkinga zabo ngokushesha same day within 30 minutes imali engena ebank imali engango 85million ukhokhela 10 kuphela kule Mali uzoyithola ngilungisa noma ziphi inkinga unazo abukho ubungozi nokusabeka anginawo umona bazalwane nazi bin inombolo baba bongani 0683103614 call or WhatsApp
# UZOMUTHOLA FUTHI NGEKE UZISOLE CALL OR
# WHATSAPP 0683103614, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 2f4d47e6-3f56-4e8e-b62b-791f2c459ac6
# Error processing message: Baba bongani CALL OR WATSSAP 0683103614
#
# ngisiza abantu izinkinga zabo ngokushesha same day within 30 minutes imali engena ebank imali engango 85million ukhokhela 10 kuphela kule Mali uzoyithola ngilungisa noma ziphi inkinga unazo abukho ubungozi nokusabeka anginawo umona bazalwane nazi bin inombolo baba bongani 0683103614 call or WhatsApp
# UZOMUTHOLA FUTHI NGEKE UZISOLE CALL OR
# WHATSAPP 0683103614, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: f2cb8786-1f92-44e2-8116-d72169a84cf9
# Error processing message: Nikombela lift Nile Pretoria west niya ka makuleke  nikhome R350, Error: Error: unsupported text language: sw, Status code: 400 , X-global-transaction-id: e3a691e0-9691-40f6-bd95-2e680af4bc6e
# Error processing message: Ni kombela lift leyi susaku hi Friday morning around 8 Hina hile Tembisa hi va mbirhi hile Tembisa, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: b9044014-1fd7-4d90-a167-dc0486fc31cf
# Error processing message: 0679397487Molweni igama lam ndingu ASIPHE MAGEBA ndise Kapa kodwa ekhaya kuse Mthatha  ndifuna ukunixelela nonke nina uba ndihlupheke ixesha elide  Ndazobona post yomnye usis onguNwabisa apha kufacebook encoma uBaba SIBIYA ngoba wamnceda ngemali esheshayo ndathi mandizame nam hleze ndngancedakala  nyan ndambhalela wathi mandithumele iAccount yam ndamnika after i1hour yangena imali kwi Account yam R5 million  awubhatali ubhatala after ingenile imali   Ndithi nani ningancami kuqale kubemnyama before kukhanye ungamfounela apha okanye whatsapp  0683266675, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: 12bdd81f-7706-495d-be7d-aa26fc67612d
# Error processing message: Sanibona bafwetu la ekhaya ngiyanithanda nonke baseMzansi ngicela ukuxwayisa izingane zakwethu Kuna abantu abadlala ngamaintshi ethu Nami ngike ngaba yisisulu salokhu bakhona abasebenzisa igama lika MBATHA ngamanga abantu banamanga Uma ngibhale lokhu ngoba ngibona igama lika Mkhulu MBATHA line zinombolo ezihlukene ngicela ulawule izinombolo Inamba kaMkhulu MBATHA  ithi 0798331815 akaze ayishitshe inombolo yakhe ngiyamazi umkhulu MBATHA  ubuso nobuso une iminyaka engu 75 yobudala yena yedwa uMkhulu wangisiza NGATHOLA imali engango R4 Million kwi account yami yena uhlala kzn kokstad  ngimvakashele  ngo February okwamanje siphila Kahle nomndeni ngavula ama business ngexa yakhe Uma nani nifuna ukuphuma ekuhluphekeni ngicela Nifonele yena bazonisiza ngiyabonga CALL OR WHATSAPP 0798331815, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 9fecfb12-d14f-4d8d-a1d3-b350139d9dfa
# Error processing message: Doney Samaroo , Error: Error: unsupported text language: gv, Status code: 400 , X-global-transaction-id: 20f88919-c95e-4204-a957-6d99d36a67fd
# Error processing message: Mholweni bethuna  ukuhlupheka ngamanye amaxesha funeka ulwe nentlupheko uthathe ndlela ezilulaMina ndandisokola kakhulu ekhaya wonke umntu ethembe mina ndandingakwazi ukubawondla
# ngokufaneleyo
#
# Bakwethu imali esheshayo yinto eyinyanikepha kuzawumele niqaphele xa udinga imali kumntu ethi ufuna imali yeskhanyiso yazi ukuthi akuyo inyani leyo
#
# ngenye imini ndathenga iphepha isolezwe lesi Xhosa ndabona tata Munyembo 0639960102 ebhalile ukuthi uyanceda ngemali ndamfounela kuthe ekuxoxeni kwethu ku whatsapp wandinika imiyalelo ndayenza yonke into owayesethi ndiyenze ngoba Noko umsebenzi wakhe awunalo igazi akathwalisi le yinyani
#
#  ndayifumana imali eyi 53million yangena kwi account yam kwangalomini yena uye umbhatale kule mali oyifumeneyo ndithetha Nani nje akhonto ndingayenzanga ekhaya mina ne family yam siphila kamnandi kakhulu ngoku ukuhlupheka akudalwanga ndingumuntu ophumeleleyo ngoku ndibonga Utata Munyembo ngokundenza umntu ndinawo ama business ngenxa yakhe Xa uyifuna inombolo yakhe ithi 0639960102 uyafoneleka naku whatsapp  uzomthola futhi, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: dbbc51ce-7d84-4f75-8cc2-8a4e71803039
# Error processing message: Akekho oyosukumela isimo sempilo
# Yakho ngaphandle kwakho
# Ukuze uphile impilo engconothatha isinqumo esoshintsha impilo Yakho nesizukulwane sakho esizayoubuhlwempu singabuqeda masibambisana sibungaze amandla amathonga
#
# Whatsapp and call 078 629 6302 Udinga malini imali ozokwazi ukujabula impilo yakho yonke  ngisho imali esheshayo ngisiza umuntu kuqala nge 32 years kuyaphezulu  umuntu ngifuna umuntu Abecrc ongithintayo kube umuntu o serious hayi umuntu onesikhathi sokudlalaImali esheshayo namuhla engena endlin R64million noma kwi account yakho iyangena noma ukude Capitec Bank  R10 million FNB Bank  R9 million ABSA Bank  R82million Nedbank R8 million Standard Bank R79million Tyme Bank R7million African Bank R6million Bidvest Bank R58million Bhala ibhange lakho bese ulinda 45 minutes ngoba umsebenzi walapha ekhaya awunabungozi ungasabe akekho umunthu azoshonayo lapho  whatsapp and call 078 629 6302, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: c7dd4e1a-b136-4e82-a58f-b79fb96582ed
# Error processing message: Ukhona ongakayitholi R350 last years Ago
#
# SASSA 2021202220232024
#
# Inbox me, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 9a67a717-15f4-4c66-86cc-890cecb4d66e
# Error processing message: TRANSPORT IHONE ZWINO UBVA THOHOYANDOU UYA GAUTENG COLL 0796382639, Error: Error: unsupported text language: unknown, Status code: 400 , X-global-transaction-id: 8e689b83-94b4-48e1-94e2-620ee9e786ad
# Error processing message: Kasi why mi hanya thyaka Mara munhu u hleketa ku hakeriwa b4 ntlaaaaaa, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: f4175915-6b21-4ae9-ba0c-3cecb8477acf
# Error processing message: Nikombela vanhu lava va yaku kaya mndzuku friday ku suka a Soweto to Giyani pls inbox me, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: 9affc366-9eff-49a5-9547-0fdd7a809c66
# Error processing message: Ni kombela vanhu vo suka Pretoria Ku ya ka Mdabula Na matiko akelani mundzuku hi 12 pm, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: b050c191-d84c-4ab8-8c5a-9277c0ca68de
# Error processing message: Yaphuma namhlanje Cape town to mthatha Whatsapp 0640718071, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: 98ceb29c-7d78-48f7-ac5b-d2c131d33a9f
# Error processing message: Molwen ndiyabulisela 0735845671 qha igama lami madlala Da million  ndihlala umzikhulu  ikhaya lise lusikisiki ndineminyaka eyi 33 ndifuna ukunixekelela isthory sami kumdala ndisebenza kodwa imali iphelela ezandleni ndizamile kuningi ndithe ndizame impilo enye  ndinamatyala wabantu ndazothi ngelinye ilanga ndivakatshele evictory  ndava omnye usis uthetha izindaba ukuthi encoma utata kassemu  banceda  izixaki izinisi ukubuyisa sthadwa sakho noba kuvimba umzi noba urhola kabini enyanga noba une inkinga mzimba wakho zinto zinisi bazokunceda noba unexhaki uzokunceda  ngoku noba unazo zixhaki zinisi thetha naye bayakwazi kunceda mina noba kanjan  nedlela amcende ngayo ngemali esheshayo ndacela andiphe le inamber ka utata kassemu hay wandinika ndafika ndamfonela ngokukhawuleza wabuza ndifuna malin ndatsho 52 million wandibuza ndifuna ingene kwi account yam qha wathi  ndimsendela  account yami ndamsendela khange wandixekelela ndilinde khuphele neh 30 minutes imali izongena ndahlala ndilinda lento uthe ndilinde yaphela 30 minutes ndabona message  yangena efoni yami  imali engango 52
# Error processing message: Sanibonani igama uThandeka ngokuhlala ngise  Goli kodwa ngizalwa Pretoria bengingazi ukuthi noma ungaba uthisha uyabanazo izinkinga zemali bengihlezi ngiyizwa indaba yobaba abasiza ngemali nami ngelinye ilanga ngangena ku Facebook ngabona post ka paster Nasimba nemniningwane yakhe ongoyena wangisiza kakhulu nami namhlanje ngiyakwazi ukugibela indiza ngiye ko Cape Town eqinisweni uyasiza lodokotela wakwazi ukungilungisela ngathola imali engango 42Million wangikhethisa ukuthi ingene ebank noma endlini uyakwazi nokuhlangana naye uma ufuna ukuhlangana naye uma ufuna usizo uyamuthola kuma calls naku WhatsApp Kule number 0677635067, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: eb471541-6fd8-4d3f-8c9d-f515b662f4bd
# Error processing message: Lift yabantu ababini 2 khona guys plz siya komani namhlanje siphuma namhlanje late, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: e7b61e65-162d-4130-af79-819a24546b9a
# Error processing message: hikombela lift from Pretoria to giyani sweswi, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: 81e3b112-fc74-4fe7-9508-53b515c2c779
# Error processing message: 0734257096 call or whatsapp  GOGO CHALO
# Imali esheshayo namuhla engena endlin 5 million noma kwi account yakho iyangena noma ukude
# Capitec Bank  R10 million
# FNB Bank  R9 million
# ABSA Bank  R7 million
# Nedbank R3 million
# Standard Bank R4 million
# Tyme Bank R5 million
# Bhala ibhange lakho bese ulinda imizuzu CALL OR WHATSAPP GOGO CHALO 0734257096lll, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 177bf55a-4225-4251-90fa-4792e1f4530d
# Error processing message: Kombela lift suka Soweto niya elim mundzuku R300, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: 6cd2817e-ab3a-4411-adc5-8e34dcc724c3
# Error processing message: Pamela John , Error: Error: not enough text for language id, Status code: 422 , X-global-transaction-id: 5bcb9230-8ef3-4992-aaa9-b5fa593d1aa5
# Error processing message: Date 23 August loyi Alavaku transport nisuka tembisa Soweto pretoria to malamulele giyani MTN 0603263948 Voda 0647769373, Error: Error: unsupported text language: unknown, Status code: 400 , X-global-transaction-id: fa2c4748-b231-49f7-ab69-6e24a6a9524e
# Error processing message: 0679397487Molweni igama lam ndingu ASIPHE MAGEBA ndise Kapa kodwa ekhaya kuse Mthatha  ndifuna ukunixelela nonke nina uba ndihlupheke ixesha elide  Ndazobona post yomnye usis onguNwabisa apha kufacebook encoma uBaba SIBIYA ngoba wamnceda ngemali esheshayo ndathi mandizame nam hleze ndngancedakala  nyan ndambhalela wathi mandithumele iAccount yam ndamnika after i1hour yangena imali kwi Account yam R5 million  awubhatali ubhatala after ingenile imali   Ndithi nani ningancami kuqale kubemnyama before kukhanye ungamfounela apha okanye whatsapp  0683266675, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: 20a52b35-b54b-414f-a26f-fe4e10023327
# Error processing message: MKHULU  MATHAMBULA
#               27762240407
# NGOKUBONGA KWAMI NGAMNIKA U 20 NGCELA UKUTHI NANI NINGALENZIPHUTHA THATHANI INAMBA YAKHO UZONISIZA NINGALAHLIMALI YENU NITHUMELA KUWONKE UMNTU OZIBIZA UKUTHI USIZABANTU  0601366590CALL OR  WHATSA, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 68e11b69-1ab1-4de1-881a-954c7feeb6f5
# Error processing message: Naveed Baloch , Error: Error: not enough text for language id, Status code: 422 , X-global-transaction-id: 861493d8-ff8d-4179-b7ec-17fbf4e33dda
# Error processing message: Goeie more almal
# Ons is opsoek na n saam ry geleentheid of n lift club vir 2 dames vanaf Spring na  Elsburg in die Oggend Ook vanaf Elsburg weer terug in die aand
# Moet voor 8 in die oggend daar wees en werk tot 5 uur in die middag Maandae tot Saterdae
# Saterdae werk is tot 2 uur
# Groot asb en baie dankie
# Kontak Brenda 069 426 3982, Error: Error: unsupported text language: af, Status code: 400 , X-global-transaction-id: 4850da68-5df5-4dc5-ae72-a34d311b1be2
# Error processing message: Avuxeni vamakweru transport yi kona this morning 22 August 2024 ku suka eka Malamulele na Giyani Pretoria Tembisa  Alex Joburg na Soweto a hi fambeni 4 people only WhatsApp 0832700039 now, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: b0a42e0a-da97-4b4f-b639-3f913759e406
# Error processing message: Dumelang kgopela lift from lebowakgomo to tembisa, Error: Error: unsupported text language: tn, Status code: 400 , X-global-transaction-id: f51d9a9f-feb6-441d-a6db-f157c6cb1c26
# Error processing message: Vanhu va mie mati tiva  transport yikona today hi 18H00 ku suka thembisa na pitori to giyani na malamulele call ni sele hi 3 space tsena 27 67 914 9604 ta mi siya makaya i private car, Error: Error: unsupported text language: ts, Status code: 400 , X-global-transaction-id: 4ced6dcc-a1d4-4365-86c8-0e5a25a3ab99
# Error processing message: Kudala uyazama ngosizo lwemali kwa abanye amadokotole akulunge tuu manje call or WhatsApp kule no 0814530439 ubone kungati awuzoyithola imali uzodinga ngayo  Amen, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 01ba8e75-a6bc-48b4-9358-87b74fec4bdb
# Error processing message: Ndiyacela ku Admini andikhangelise umntu othengisa nkabi ze bhokwe eMQanduli zibe light brown please ndiyaxolisa kuba ayiyo group yalonto ndibethwa kukuxakeka sisi wam wenza msebenzi, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: cfd1352b-6db1-4798-9875-cc77cc830543
# Error processing message: Osebenzisa MTN akeze ngimsize nge airtime yamahhala wozani  free data, Error: Error: unsupported text language: zu, Status code: 400 , X-global-transaction-id: 0224fab7-4732-4e2e-b641-10b0318749c1
# Error processing message: Molweni 0670328050Igama lami ndingu amanda mie ndihlala emthatha bt ekhaya kuse Cape town ndifuna ukunixelela nina nokha uba ndihluphekile ixesha elide ndikhangela luncendo lwemali esheshayo kondwa bendilahla nje imali zam emva kokubona ipost yomnye usisi Igama lake wendy apa ku fecebook umncoma ugogo chinazo nam ndat mandizame kokungcina ndatheta naye ugogo chinazo wacela account number yami ndamunika nyan uthi ndilinde nge 30 minutes
ba andilinde kude kuphele inyanga ndizokwazi ukukhupha isikhanyiso ukuze azoqala ukundilungiselela kuba ndandifuna imali ekhawulezayo kulenyanga iphelile ndayorhola imali abantwana bami yegrent ndamthumela isinkhanyiso   wathi ndilinde ixesha elingango 3hrs ndalinda kodwa ndazixelela uba udlala ngami kodwa emveni kwalo 3hrs  yangena imali kwi Absa Account yam zange ndikholwe ngoba kaloku baninzi besixokisa baba bengenzi kwalonto ndamfounela ke ndimkhangela ukuba kwenzekile nyani na yaye ndingahamba ndiyoyikhupha le mali naWathi ewe yimali yam leyo zange ndiphindele kwakwelo kitshi ndayothatha imali yam ndabhatala utata isiqingatha esasivumelene ngaso tjoo yemka indlala ekhaya ndokha ekhaya lam ndithetha nani nje ndimnqwenelela okuhle kodwa lo tata kunye nala tata wayengazange Abe nomona ngendlela afumene ngalo uncedo Yanga uThixo angabagcina abasikelele ngoba ngoku ndine zam iBusines ndipost uba nawe uphila kwimeko ebifana neyami andinamona nantsi inumber yake  0679682384ku call or WHATSAPP enkos, Error: Error: unsupported text language: xh, Status code: 400 , X-global-transaction-id: 465721a9-40ab-4af7-a71b-2b64763277b5
# ...
#
# CallWhatsApp 078 322 6312, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 1200 and 1300
#
# CallWhatsApp 078 322 6312, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 2 to 3 pmcall or WhatsApp 083 671 5316, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE
# 220824 around 91011
#             book on
#         0608013531
#
# Return  from PE to EL
#                around
#           14001500, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 2 to 3 pmcall or WhatsApp 083 671 5316, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered btwn 89am today from EL to PE
#
# Please call or whatsapp 0733020029
#
# Taking parcels as well, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 1200 and 1300
#
# CallWhatsApp 078 322 6312, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 2 to 3 pmcall or WhatsApp 083 671 5316, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 2 to 3 pmcall or WhatsApp 083 671 5316, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 2 to 3 pmcall or WhatsApp 083 671 5316, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 9am and 10am
#
# CallWhatsApp 078 322 6312, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE Saturday at 10am to 11am  13pm to 14pm
# 0634442288, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 0900 and 1000
#
# CallWhatsApp 078 322 6312, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered btwn 78am today from EL to PE
#
# Please call or whatsapp 0733020029
#
# Taking parcels as well, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE
# 220824 around 89 am plz call or whats app me 0608013531
# Return from PE to EL around 14001500, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 1300 and 1400
#
# Any size luggage is accepted
#
# CallWhatsApp 076 484 9915, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE this morning between 9  10am
# CallWhatsapp 0784436129, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 1000 and 1100
#
# CallWhatsApp 078 322 6312, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 0900 and 1000
#
# CallWhatsApp 078 322 6312, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 9am and 10am
#
# Any size luggage is accepted
#
# CallWhatsApp 076 484 9915, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered now till 800am from EL to PE
#
# Call or whatsapp 076 777 6410, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 1300 and 1400
#
# Any size luggage is accepted
#
# CallWhatsApp 076 484 9915, Departure: from EL, Arrival: to PE
# Request: Space available from EL to PE nowand back from PE to EL sameday
# Call or WhatsApp 083 896 5602 if you need a ride, Offer: Lift offered from EL to PE between 1300 and 1400
#
# Any size luggage is accepted
#
# CallWhatsApp 076 484 9915, Departure: from EL, Arrival: to PE
# Request: lift for 2 adults requested from EL to Queenstown on Friday the 23rd Preferably midmorning Pls inbox, Offer: Lift offered from EL to Qtn tomorrow morning 22082024
# 0729044803, Departure: from EL, Arrival: to Q
# Request: lift for 2 adults requested from EL to Queenstown on Friday the 23rd Preferably midmorning Pls inbox, Offer: Lift offered from EL to Qtn tomorrow morning 22082024
# 0729044803, Departure: from EL, Arrival: to Q
# Request: lift for 2 adults requested from EL to Queenstown on Friday the 23rd Preferably midmorning Pls inbox, Offer: Lift offered from EL to Qtn tomorrow morning via KWT 22082024
# 0729044803, Departure: from EL, Arrival: to Q
# Request: lift for 2 adults requested from EL to Queenstown on Friday the 23rd Preferably midmorning Pls inbox, Offer: Lift offered from EL to Qtn tomorrow morning 22082024
# 0729044803, Departure: from EL, Arrival: to Q
# Request: lift for 2 adults requested from EL to Queenstown on Friday the 23rd Preferably midmorning Pls inbox, Offer: Lift offered Friday at 1800 from EL to Queenstown I have 4 spaces, Departure: from EL, Arrival: to Q
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good day bafethu
#
# Lift offered
#
# From Lusikisiki
# To Joburg
# Date 25 August 2024
# Time 0900am sharp
# Price R550
#
# Durban
# Time 1330
# Price R380
#
# If interested please contact me via inbox, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good day bafethu
#
# Lift offered
#
# From Lusikisiki
# To Joburg
# Date 25 August 2024
# Time 0900am sharp
# Price R550
#
# Durban
# Time 1330
# Price R380
#
# If interested please contact me via inbox, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good day bafethu
#
# Lift offered
#
# From Lusikisiki
# To Joburg
# Date 25 August 2024
# Time 0900am sharp
# Price R550
#
# Durban
# Time 1330
# Price R380
#
# If interested please contact me via inbox, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Lift offered  tomorrow  morning
# 0500  0600
#
# 4rmPE  TO  East  London
#
# Door to door  lift
# 10ns 0631039219 can dm  watspp or call
# To book ur space intime, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good day bafethu
#
# Lift offered
#
# From Lusikisiki
# To Joburg
# Date 25 August 2024
# Time 0900am sharp
# Price R550
#
# Durban
# Time 1330
# Price R380
#
# If interested please contact me via inbox, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good evening family SAplumbing Everytimewe are offering the following services PLUMBING TILLING PAINTING PAVEMENT BUILDING AND RENOVATIONS
# YOU CAN CALL OR WHATSAPP 074 966 9032  OR 062 635 6589, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Ladies and Gentlemen kindly be alerted of scammers Samantha transport is one of them posts in groups like these and takes advantage from honest people They will ask u to book and give u the account numbers please dont fall for them It seems like its partners or what but normally they post on such groups of lifts etcTheir numbers are as follows 0682535696 if they text u or offer u a lift block themThey scammed R500 afterwards deleted their texts and blocked meand Im not the only one they tricked, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: We offer transportation for STELLENBOSCHKLAPMUTSPAARLWELLINGTONFRANSCHOEK
#
#  COMPANY STAFF
#  EHAILING SERVICES
#  AIRPORT DROP OFFPICKUP
#  LONG SHORT DISTANCE TRAVEL
#  SCHOOL TRANSPORT
#
# CALL 068 115 9900 or WhatsApp 27 71 967 9846, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: LIFT OFFERED TOMORROW MORNING FROM EL TO PE BETWEEN 7 AND 8
# PLEASE CONTACT OR WHATSAPP ME ON 0838965602, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Lift offered Wednesday afternoon 28 August MIDRAND  DBN WhatsApp 0713319267, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Mholo lift offered abantu ababini namhlanje from cape Town to ngcobo phuma lyt ngo 6, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: CV Services
# Get your CV Revamped or have it written from scratch
# I offer professional CV Revamp Services to jobseekers who wants their CVs to be professionally updated and well presented to potential employers
#
# Clean  Professional Cv
# Latest design with perfect presentation
# ATS System Compliant Cv
# 100 Satisfaction
#
# ORIGINAL PRICES
# 1 CV only R60
# 2 Get both CV and Cover Letter for only R70
# 3Cover Letter For R20
#
#
# Lets fight the unemployment rate
#
# Text me on WhatsApp 0766851482, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good day bafethu
#
# Lift offered
#
# From Lusikisiki
# To Joburg
# Date 25 August 2024
# Time 0900am sharp
# Price R550
#
# Durban
# Time 1330
# Price R380
#
# If interested please contact me via inbox, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Lift offered  tomorrow morning 200824
#
# From  PE  TO  Cape  Town
#
# Time 0900  1000
#
# Dgts0631039219 can watspp or call, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Lift offered 210824
#
# Dbn to jhb, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Private Lift club offered from phoenix unit 23457 to pinetown Monday to friday Contact 0849100989, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Lift offered  tomorrow  200824
#
# From PE  TO  CAPE TOWN
#
# TIME 0900  1000
#
# Dgts 0631039219 can watspp or call, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Lift club offered
# From
# Effingham  Greenwood Prk
# To Mt Edgecombe
# Monday to fridays
# 7am to 5pm
# 0725858784, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Offering lift from plett to pe contact 0693952497, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good day bafethu
#
# Lift offered
#
# From Joburg
# To LusikisikiFlagstaff via N3 Durban
# Date 08 August 2024
# Time 1800pm sharp
# Price R600
#
# Durban R350
#
# If interested please contact me via inbox, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Lift club offered from umhlatuzana to riverhorse Valley imvubupark
# 8am430pm
# Monfri
# 074 746 3613, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Ndaa makhuwa
#
# Transport ihone Friday 160824 after working hours from gauteng strictly around DiepslootTembisaOlivenCenturionCosmoAtteridgevillePTA CENTRAL to venda around Maila watervaal mbhokota chavani  muilamulimapfanananimukondenimashambasereni u  swika nga muwaweni
#
# For Bookings and confirmations call or whatsapp us on 071 465 2845
#
# A private car with comfortwe offer door to door services, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Good day bafethu
#
# Lift offered
#
# From Lusikisiki
# To Joburg
# Date 25 August 2024
# Time 0900am sharp
# Price R550
#
# Durban
# Time 1330
# Price R380
#
# If interested please contact me via inbox, Departure: None, Arrival: None
# Request: Removal Transport and Courier Services  Transporters and Load Requests  083 729 8133, Offer: Liftclub offered from chatsworth to merebankjacobs and bluff near mall
# Times8 to 2
# Whatsappkrishen0631715716, Departure: None, Arrival: None
